# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('123.png')
res = cv2.resize(img,None,fx=5,fy=5,interpolation= cv2.INTER_LINEAR)

# %%
cv2.namedWindow('image')

while(1):
    cv2.imshow('image',img)
    k=cv2.waitKey(1)&0xFF
    if k== 27:
        break
    
cv2.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lgosc\IP2024\chap 1.4.3.ipynb 셀 3 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/lgosc/IP2024/chap%201.4.3.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> while(1):
#       <a href='vscode-notebook-cell:/c%3A/Users/lgosc/IP2024/chap%201.4.3.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     cv2.imshow('image',img)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lgosc/IP2024/chap%201.4.3.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     k=cv2.waitKey(1)&0xFF
#       <a href='vscode-notebook-cell:/c%3A/Users/lgosc/IP2024/chap%201.4.3.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     if k== 27:
#       <a href='vscode-notebook-cell:/c%3A/Users/lgosc/IP2024/chap%201.4.3.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>         break
#
# KeyboardInterrupt:

# %%
img = cv2.imread('123.png')
rows, cols = img.shape[1,2]
M = np.float32([1, 0, 100],[0, 1, 50])
dst = cv2.warpAffine(img, M(cols, rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('123.png')
rows, cols = img.shape[:2]
M = cv2.getRotationMatrix2D((cols/4, rows/4), 45, 1)
dst = cv2.warpAffine(img, M(cols, rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('123.png')
rows,cols,ch = img.shape

pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
    
M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('IMG_6504.JPG')
rows,cols,ch = img.shape

pts1 = np.float32([[180,240],[820,220],[820,520],[100,1080]])
pts2 = np.float32([[0,0],[400,0],[400,600],[0,600]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(400,600))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu2.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[180,240],[820,220],[820,50],[180,500]])
pts2 = np.float32([[0,0],[820,0],[820,500],[0,500]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(820,500))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
